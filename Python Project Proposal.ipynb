# %%
#DSO599: Intro to Python in Business Analytics
#Authors: Dan Zhang, Jack Lin, Yaqing Wei, Ashley Moon

#Questions to address using the dataset:
##

import pandas as pd

shopify=pd.read_csv('shopify_app_store/apps.csv')
shopify
# Out:
#                                                     url  \
# 0     https://apps.shopify.com/hide-paypal-and-other...
# 1                   https://apps.shopify.com/quick-pick
# 2            https://apps.shopify.com/printout-designer
# 3                    https://apps.shopify.com/cartsguru
# 4           https://apps.shopify.com/related-blog-posts
# 5                        https://apps.shopify.com/flits
# 6                      https://apps.shopify.com/dropwow
# 7     https://apps.shopify.com/google-express-integr...
# 8                 https://apps.shopify.com/carecart-pro
# 9        https://apps.shopify.com/awesome-store-locator
# 10    https://apps.shopify.com/dhl-discounted-shippi...
# 11                    https://apps.shopify.com/quantify
# 12                    https://apps.shopify.com/zero-out
# 13                https://apps.shopify.com/orderlyprint
# 14               https://apps.shopify.com/wherever-chat
# 15                   https://apps.shopify.com/instashop
# ...
